# %%
a = [1,2,3,4,5,6]
for i in a :
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
li = list()
for i in range(5):
  for j in range(i):
    li.append(i)
print(li)
# Out:
# [1, 2, 2, 3, 3, 3, 4, 4, 4, 4]

# %%
li = list()
for i in range(5):
  for j in range(i):
    print(i)
# Out:
# 1
# 2
# 2
# 3
# 3
# 3
# 4
# 4
# 4
# 4
